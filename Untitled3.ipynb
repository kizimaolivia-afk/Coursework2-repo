# %% [markdown]
# <a href="https://colab.research.google.com/github/kizimaolivia-afk/Coursework2-repo/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
STUDENT_ID = "YOUR_ID"
COHORT = "CML3112"

# %%
print("Hello from CML3112")
proof_sum = 2 + 2
print(proof_sum)
# Out:
# Hello from CML3112
# 4

# %%
readings = 12

# %%
readings = readings + 5
print(readings)
# Out:
# 17

# %%
import csv
with open("site_inspection_log.csv", newline="") as f:
    rows = list(csv.DictReader(f))
print(len(rows))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_474/1480748277.py in <cell line: 0>()
#       1 import csv
# ----> 2 with open("site_inspection_log.csv", newline="") as f:
#       3     rows = list(csv.DictReader(f))
#       4 print(len(rows))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'site_inspection_log.csv'
