# %% [markdown]
# <a href="https://colab.research.google.com/github/kizimaolivia-afk/Coursework2-repo/blob/main/04_hidden_state.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Break and fix
# Predict the error, run it, explain its cause and repair it.

# %%
readings = 12
readings = readings + 5
print(readings)  # expected fresh-run result: 17
# Out:
# 17
