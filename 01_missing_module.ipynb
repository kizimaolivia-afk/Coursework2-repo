# %% [markdown]
# <a href="https://colab.research.google.com/github/kizimaolivia-afk/Coursework2-repo/blob/main/01_missing_module.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Break and fix
# Predict the error, run it, explain its cause and repair it.

# %%
import math
print(math.sqrt(25))
# Out:
# 5.0

# %% [markdown]
# Cause: Python cannot find the module course_package_not_installed because it is not installed or does not exist in the python environment.
# Solution:Replace the incorrect module name with the correct module, or install the required package before importing it.
