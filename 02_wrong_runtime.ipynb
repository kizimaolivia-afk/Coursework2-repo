# %% [markdown]
# <a href="https://colab.research.google.com/github/kizimaolivia-afk/Coursework2-repo/blob/main/02_wrong_runtime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Break and fix
# Predict the error, run it, explain its cause and repair it.

# %%
import sys
assert sys.version_info.major == 3, "Notebook expects Python 2, but the course uses Python 3"

# %% [markdown]
# The code is intentionally checking which version of python you are running. The line assert sys.version_info.major == 2 is a test. it says, "I assert (demand) that the major version of python currently running is exactly 2." Solution: Since the error message itself states, "the course python 3," the assertion is currently wrong and needs to be updated to match the environment. To fix it, change the number 2 to 3 in the assert statement
