# %% [markdown]
# <a href="https://colab.research.google.com/github/kizimaolivia-afk/Coursework2-repo/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Calculate normal stress

force = 50000       # Force in N
area = 0.002        # Cross-sectional area in m^2

stress = force / area

print("Force:", force, "N")
print("Area:", area, "m^2")
print("Normal stress:", stress, "Pa")
# Out:
# Force: 50000 N
# Area: 0.002 m^2
# Normal stress: 25000000.0 Pa
